# %%
pip install nltk
# Out:
# Requirement already satisfied: nltk in c:\users\sakshi verma\anaconda3\lib\site-packages (3.9.2)
# Requirement already satisfied: click in c:\users\sakshi verma\anaconda3\lib\site-packages (from nltk) (8.2.1)
# Requirement already satisfied: joblib in c:\users\sakshi verma\anaconda3\lib\site-packages (from nltk) (1.5.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\sakshi verma\anaconda3\lib\site-packages (from nltk) (2025.9.1)
# Requirement already satisfied: tqdm in c:\users\sakshi verma\anaconda3\lib\site-packages (from nltk) (4.67.1)
# Requirement already satisfied: colorama in c:\users\sakshi verma\anaconda3\lib\site-packages (from click->nltk) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
import nltk
nltk.download("punkt")
nltk.download("punkt_tab")
nltk.download("stopwords")
nltk.download("wordnet")
nltk.download("averaged_perceptron_tagger")
# Out:
# [nltk_data] Downloading package punkt to C:\Users\SAKSHI
# [nltk_data]     VERMA\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# [nltk_data] Downloading package punkt_tab to C:\Users\SAKSHI
# [nltk_data]     VERMA\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt_tab.zip.
# [nltk_data] Downloading package stopwords to C:\Users\SAKSHI
# [nltk_data]     VERMA\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# [nltk_data] Downloading package wordnet to C:\Users\SAKSHI
# [nltk_data]     VERMA\AppData\Roaming\nltk_data...
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\SAKSHI VERMA\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping taggers\averaged_perceptron_tagger.zip.
# True

# %%
from nltk.tokenize import sent_tokenize

text = "python is easy. NLP is interesting. AI is growing."

sentences = sent_tokenize(text)

print(sentences)
# Out:
# ['python is easy.', 'NLP is interesting.', 'AI is growing.']

# %%
# Stop Word Removal
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

text = "I am learning python using NLTK"
words = word_tokenize(text)

stop_words = set(stopwords.words("english"))

filtered = []
for word in words:
    if word.lower() not in stop_words:
        filtered.append(word)

print(filtered)
# Out:
# ['learning', 'python', 'using', 'NLTK']

# %%
# Stemming
from nltk.stem import PorterStemmer

stemmer = PorterStemmer()

words = [
    "Playing",
    "Played",
    "Plays",
    "Player"
]
for word in words:
    print(word,"→",stemmer.stem(word))
# Out:
# Playing → play
# Played → play
# Plays → play
# Player → player
